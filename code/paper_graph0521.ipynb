# %%
# sevrity - diffrent level IR from
# 1.实验分析，
# 研究内容，severity对全局模型的影响
# 研究方法
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
# setting_name = 'CovA_Abrupt_BtoVH'
analysis_list = ['CovA_Abrupt_BtoL','CovA_Abrupt_BtoM','CovA_Abrupt_BtoH','CovA_Abrupt_BtoVH','Balanced' ]
# analysis_list =['IncrementalSampling','RandomUnderSampler','Triplets','RandomOverSampler','no','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#3b5489','#15a28c', '#59b9d0', '#e8513a', '#3e6999','#f39d82']
label_list = ['BtoL','BtoM','BtoH','BtoVH','all-B']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-','--', '-', '-', '-',(0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['s','*','p','o','|','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 6, label=label_list[i], linewidth=4)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16
# 显示图例和网格线, frameon=False去除外边框
ax.legend(loc=(0.02,1.02),fontsize=26, frameon=False, ncol=3)

ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 1.实验分析，
# 研究内容，sampling 对BtoVH 的影响
# 研究方法
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
setting_name = 'CovA_Abrupt_BtoVH'
analysis_list =['RandomUnderSampler','IncrementalSampling','Triplets','RandomOverSampler','No','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#038583','#e62816','#0c8d4a','#603076','#394793','tab:green', 'tab:purple', 'tab:cyan','#FF5200']
# label_list = ['Balanced','BtoL','BtoM','BtoH','BtoVH']
label_list = ['RUS','Our','Triplets','ROS','No','CNN']
line_styles = ['--','-', '-', (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
# line_styles = ['--','-', '-', '-', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = [None,None,'p','x','s','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    # metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    metric_path = os.path.join(base_path,algorithm,setting_name,f'{analysis}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 10, label=label_list[i], linewidth=5)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 2 Speed
# 2.实验分析，
# 研究内容，speed对全局模型的影响
# 研究方法 Incremental，abrupt,gradual
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
# setting_name = 'CovA_Abrupt_BtoVH'
analysis_list = ['Balanced','covA_Incremental_50_dirF','CovA_Abrupt_BtoVH','Gradual2','CovA_severityVH']
# analysis_list =['IncrementalSampling','RandomUnderSampler','Triplets','RandomOverSampler','no','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#FF5200', '#0972c4', '#c8531c','#f2b120', '#7c2f8f','tab:red']
label_list = ['all-B','Incremental','Abrupt','Gradual','all-VH']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-',':','-', '-',  (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['|','^','p','x','s','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 8, label=label_list[i], linewidth=4)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
setting_name = 'Gradual'
analysis_list =['RandomUnderSampler','IncrementalSampling','Triplets','RandomOverSampler','No','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#038583','#e62816','#ed8522','#603076','#394793','tab:green', 'tab:purple', 'tab:cyan','#FF5200']
# label_list = ['Balanced','BtoL','BtoM','BtoH','BtoVH']
label_list = ['RUS','Our','Triplets','ROS','No','CNN']
line_styles = ['-','--', '-', (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
# line_styles = ['--','-', '-', '-', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['|','^','p','x','+','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    # metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    metric_path = os.path.join(base_path,algorithm,setting_name,f'{analysis}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 10, label=label_list[i], linewidth=3)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 3,frequency
# 实验1.
# 所有客户都端的
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling/'
algorithm = 'FedNova'
setting_name = 'Rc1c2_Frequency_10VH'
sampling_name = 'no'
analysis_parameter = 'accuracy'


fig, ax = plt.subplots(figsize=(12, 8))

# 创建一个颜色列表，分别用于不同的 client_id
light_colors = ['tab:pink', 'tab:orange', 'tab:olive', '#ff0303','tab:brown' ]
dark_colors = ['tab:purple', 'tab:blue', 'tab:gray', 'tab:green', 'tab:cyan']
# # 'Recurrence','unPredictability','Correlation','Direction_BvsVH_noGB','Direction_VHvsVHR_GB'
# 'Balanced','CovA_SeverityVH','CovA_severityVHR'
color_list = ['tab:red', 'tab:green', 'tab:purple', 'tab:green']
reff_list = [ 'CovA_severityVHR','CovA_SeverityVH']
# 读取全局数据
label_list = [ '98/2 (VHR)','2/98 (VH)']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-','-', '-', ':', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['p','x','s','o' ]
# axins = ax.inset_axes([1.1, 0, 0.69, 1.0])

read_balanced_path = 'E:/FedStream/metrics/130K_binary_client_Sampling/FedNova/Rc1c2_Frequency_10VH/no_epoch200_1/global_back.csv'
dfb = pd.read_csv(read_balanced_path)
# accuracyb = dfb['accuracy']
gdb = dfb.groupby('rounds')['accuracy'].mean()
xb = gdb.index.values
accuracyb=gdb.values
ax.plot(xb, accuracyb, color='black',linestyle='-',marker='p',markersize = 8, label='Frequency',linewidth = 5)
for i,analysis in enumerate(reff_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color = color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i], linewidth=3)
    # axins.plot(rounds, mean_accuracy,color = color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i], linewidth=3)

# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.82])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0,1.02),fontsize=35, frameon=False,ncol = 2)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
setting_name = 'Rc1c2_Frequency_10VH'
analysis_list =['RandomUnderSampler','IncrementalSampling','Triplets','RandomOverSampler','No','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#038583','#e62816','#0c8d4a','#603076','#394793','tab:green', 'tab:purple', 'tab:cyan','#FF5200']
# label_list = ['Balanced','BtoL','BtoM','BtoH','BtoVH']
label_list = ['RUS','Our','Triplets','ROS','No','CNN']
line_styles = ['--','-', '-', (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
# line_styles = ['--','-', '-', '-', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = [None,None,'p','x','s','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    # metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    metric_path = os.path.join(base_path,algorithm,setting_name,f'{analysis}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 6, label=label_list[i], linewidth=3)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 4.reccurrence
# sevrity - diffrent level IR from
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
# setting_name = 'CovA_Abrupt_BtoVH'# unpredictable
analysis_list = ['Balanced','Recurrence']
# analysis_list =['IncrementalSampling','RandomUnderSampler','Triplets','RandomOverSampler','no','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#3b5489','#15a28c', '#59b9d0', '#e8513a', '#3e6999','#f39d82']
label_list = ['all-B','Recurrence']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-','--', '-', '-', '-',(0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['s','*','p','o','|','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 8, label=label_list[i], linewidth=4)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16
# 显示图例和网格线, frameon=False去除外边框
ax.legend(loc=(0.02,1.02),fontsize=35, frameon=False, ncol=2)

ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
setting_name = 'Recurrence'
analysis_list =['RandomUnderSampler','IncrementalSampling','Triplets','RandomOverSampler','No','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#038583','#e62816','#0c8d4a','#603076','#394793','tab:green', 'tab:purple', 'tab:cyan','#FF5200']
# label_list = ['Balanced','BtoL','BtoM','BtoH','BtoVH']
label_list = ['RUS','Our','Triplets','ROS','No','CNN']
line_styles = ['--','-', '-', (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
# line_styles = ['--','-', '-', '-', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = [None,None,'p','x','s','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    # metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    metric_path = os.path.join(base_path,algorithm,setting_name,f'{analysis}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 6, label=label_list[i], linewidth=3)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 5,不可预测性
# sevrity - diffrent level IR from
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
# setting_name = 'CovA_Abrupt_BtoVH'
analysis_list = ['Balanced', 'Recurrence','unPredictability']
# analysis_list =['IncrementalSampling','RandomUnderSampler','Triplets','RandomOverSampler','no','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#3b5489','#e8513a','#15a28c', '#59b9d0', '#e8513a', '#3e6999','#f39d82']
label_list = ['all-B', 'Recurrence','Unpredictable']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-','--', '-', '-', '-',(0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['s','*','p','o','|','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 8, label=label_list[i], linewidth=4)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16
# 显示图例和网格线, frameon=False去除外边框
ax.legend(loc=(0.02,1.02),fontsize=30, frameon=False, ncol=2)

ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
setting_name = 'unPredictability'
analysis_list =['RandomUnderSampler','IncrementalSampling','Triplets','RandomOverSampler','No','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#038583','#e62816','#0c8d4a','#603076','#394793','tab:green', 'tab:purple', 'tab:cyan','#FF5200']
# label_list = ['Balanced','BtoL','BtoM','BtoH','BtoVH']
label_list = ['RUS','Our','Triplets','ROS','No','CNN']
line_styles = ['--','-', '-', (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
# line_styles = ['--','-', '-', '-', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = [None,None,'p','x','s','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    # metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    metric_path = os.path.join(base_path,algorithm,setting_name,f'{analysis}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 6, label=label_list[i], linewidth=3)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# analysis_list = ['Balanced','Cov9B_SeverityVH','CovH_SeverityVH','Cov1B_SeverityVH','CovA_SeverityVH','CovA_severityVHR']
# 6,covertype
# sevrity - diffrent level IR from
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
# setting_name = 'CovA_Abrupt_BtoVH'
analysis_list = ['Balanced','Cov9B_SeverityVH','CovH_SeverityVH','Cov1B_SeverityVH','CovA_SeverityVH' ]
# analysis_list =['IncrementalSampling','RandomUnderSampler','Triplets','RandomOverSampler','no','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#3b5489','#15a28c', '#59b9d0', '#e8513a', '#3e6999','#f39d82']
label_list = ['all-B','9B-1VH','5B-5VH','1B-9VH','all-VH']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-','--', '-', '-', '-',(0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['s','*','p','o','|','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 8, label=label_list[i], linewidth=4)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('FedNova:Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16
# 显示图例和网格线, frameon=False去除外边框
ax.legend(loc=(0.02,1.02),fontsize=25, frameon=False, ncol=3)

ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# analysis_list = ['Balanced','Cov9B_SeverityVH','CovH_SeverityVH','Cov1B_SeverityVH','CovA_SeverityVH','CovA_severityVHR']
# 6,covertype
# sevrity - diffrent level IR from
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedAvg'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
# setting_name = 'CovA_Abrupt_BtoVH'
analysis_list = ['Balanced','Cov9B_SeverityVH','CovH_SeverityVH','Cov1B_SeverityVH','CovA_SeverityVH']
# analysis_list =['IncrementalSampling','RandomUnderSampler','Triplets','RandomOverSampler','no','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#3b5489','#15a28c', '#59b9d0', '#e8513a', '#3e6999','#f39d82']
label_list = ['all-B','9B-1VH','5B-5VH','1B-9VH','all-VH']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-','--', '-', '-', '-',(0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['s','*','p','o','|','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 8, label=label_list[i], linewidth=4)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('FedAvg:Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16
# 显示图例和网格线, frameon=False去除外边框
ax.legend(loc=(0.02,1.02),fontsize=25, frameon=False, ncol=3)

ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# analysis_list = ['Balanced','Cov9B_SeverityVH','CovH_SeverityVH','Cov1B_SeverityVH','CovA_SeverityVH','CovA_severityVHR']
# 6,covertype
# sevrity - diffrent level IR from
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedProx'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
# setting_name = 'CovA_Abrupt_BtoVH'
analysis_list = ['Balanced','Cov9B_SeverityVH','CovH_SeverityVH','Cov1B_SeverityVH','CovA_SeverityVH']
# analysis_list =['IncrementalSampling','RandomUnderSampler','Triplets','RandomOverSampler','no','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#3b5489','#15a28c', '#59b9d0', '#e8513a', '#3e6999','#f39d82']
label_list = ['all-B','9B-1VH','5B-5VH','1B-9VH','all-VH']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-','--', '-', '-', '-',(0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['s','*','p','o','|','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 8, label=label_list[i], linewidth=4)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('FedAvg:Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16
# 显示图例和网格线, frameon=False去除外边框
ax.legend(loc=(0.02,1.02),fontsize=25, frameon=False, ncol=3)

ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 7.异步Rc1c2_Asyn_step7
# analysis_list = ['Balanced','Cov9B_SeverityVH','CovH_SeverityVH','Cov1B_SeverityVH','CovA_SeverityVH','CovA_severityVHR']
# 6,covertype
# sevrity - diffrent level IR from
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
# setting_name = 'CovA_Abrupt_BtoVH'
analysis_list = ['Balanced','Rc1c2_Asyn_step7','CovA_SeverityVH','CovA_SeverityVHR'  ]
# analysis_list =['IncrementalSampling','RandomUnderSampler','Triplets','RandomOverSampler','no','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#3b5489','black', '#59b9d0', '#e8513a', '#3e6999','#f39d82']
label_list = ['all-B','Asyn','all-VH','all-VHR']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-','--', '-', '-', '-',(0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['s','*','p','o','|','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 8, label=label_list[i], linewidth=4)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])

list_df_dirF = []
# E:\Fedstream\metrics\130K_binary_client_Sampling\FedNova\Rc1c2_Asyn_step7\no_epoch200_1/client_0_metrics.csv
for j in range(10):
    metric_path1 = os.path.join(base_path,algorithm,setting_name,f'{sampling_name}_epoch200_1',f'client_{j}_metrics.csv')
    # metric_path2 = os.path.join(base_path,algorithm,setting_name,f'{sampling_name}_epoch200_1',f'client_{j+5}_metrics.csv')
    df1 =pd.read_csv(metric_path1)
    # df2 = pd.read_csv(metric_path2)
    grouped_data1 = df1.groupby('rounds')['accuracy'].mean()
    # grouped_data2 = df2.groupby('rounds')['accuracy'].mean()
    list_df_dirF.append(grouped_data1)
    # list_df_dirB.append(grouped_data2)

 # 将list中的所有数据框按列拼接
combined_df1 = pd.concat(list_df_dirF, axis=1)
# combined_df2 = pd.concat(list_df_dirB, axis=1)

# 计算每一行的平均值
averaged_data1 = combined_df1.mean(axis=1)
# averaged_data2 = combined_df2.mean(axis=1)

# 获取 rounds 和平均 accuracy
rounds = averaged_data1.index.values
mean_accuracy1 = averaged_data1.values
# mean_accuracy2 = averaged_data2.values

# 绘制准确率图表
plt.plot(rounds, mean_accuracy1, label=f'Average',marker='*',linewidth=4)
# plt.plot(rounds, mean_accuracy2, label=f'Mean-half(5-9)',marker='X',linewidth=4)
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16
# 显示图例和网格线, frameon=False去除外边框
ax.legend(loc=(0.02,1.02),fontsize=25, frameon=False, ncol=3)

ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
setting_name = 'Rc1c2_Asyn_step7'
analysis_list =['RandomUnderSampler','IncrementalSampling','Triplets','RandomOverSampler','No','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#038583','red','#0c8d4a','#603076','#394793','tab:green', 'tab:purple', 'tab:cyan','#FF5200']
# label_list = ['Balanced','BtoL','BtoM','BtoH','BtoVH']
label_list = ['RUS','Our','Triplets','ROS','No','CNN']
line_styles = ['--','-', '-', (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
# line_styles = ['--','-', '-', '-', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = [None,None,'p','x','s','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    # metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    metric_path = os.path.join(base_path,algorithm,setting_name,f'{analysis}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 6, label=label_list[i], linewidth=3)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 8.direction-global Balanced
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling/'
algorithm = 'FedNova'
setting_name = 'Direction_VHvsVHR_GB'
sampling_name = 'no'
analysis_parameter = 'accuracy'

fig, ax = plt.subplots(figsize=(12, 8))

# 创建一个颜色列表，分别用于不同的 client_id
light_colors = ['tab:pink', 'tab:orange', 'tab:olive', '#ff0303','tab:brown' ]
dark_colors = ['tab:purple', 'tab:blue', 'tab:gray', 'tab:green', 'tab:cyan']
# # 'Recurrence','unPredictability','Correlation','Direction_BvsVH_noGB','Direction_VHvsVHR_GB'
# 'Balanced','CovA_SeverityVH','CovA_severityVHR'
color_list = ['tab:red', 'black', 'tab:purple', 'tab:green']
reff_list = ['Balanced','Direction_VHvsVHR_GB','CovA_severityVHR','CovA_SeverityVH']
# 读取全局数据
label_list = ['Balanced','Global','98/2 (VHR)','2/98 (VH)']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-','-', '-', ':', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['p','x','s','o' ]
# axins = ax.inset_axes([1.1, 0, 0.69, 1.0])
for i,analysis in enumerate(reff_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color = color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i], linewidth=5)
    # axins.plot(rounds, mean_accuracy,color = color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i], linewidth=5)

list_df_dirF = []
list_df_dirB = []
# E:\Fedstream\metrics\130K_binary_client_Sampling\FedNova\Rc1c2_Asyn_step7\no_epoch200_1/client_0_metrics.csv
for j in range(5):
    metric_path1 = os.path.join(base_path,algorithm,setting_name,f'{sampling_name}_epoch200_1',f'client_{j}_metrics.csv')
    metric_path2 = os.path.join(base_path,algorithm,setting_name,f'{sampling_name}_epoch200_1',f'client_{j+5}_metrics.csv')
    df1 =pd.read_csv(metric_path1)
    df2 = pd.read_csv(metric_path2)
    grouped_data1 = df1.groupby('rounds')['accuracy'].mean()
    grouped_data2 = df2.groupby('rounds')['accuracy'].mean()
    list_df_dirF.append(grouped_data1)
    list_df_dirB.append(grouped_data2)

 # 将list中的所有数据框按列拼接
combined_df1 = pd.concat(list_df_dirF, axis=1)
combined_df2 = pd.concat(list_df_dirB, axis=1)

# 计算每一行的平均值
averaged_data1 = combined_df1.mean(axis=1)
averaged_data2 = combined_df2.mean(axis=1)

# 获取 rounds 和平均 accuracy
rounds = averaged_data1.index.values
mean_accuracy1 = averaged_data1.values
mean_accuracy2 = averaged_data2.values

# 绘制准确率图表
plt.plot(rounds, mean_accuracy1, label=f'Average(0-4)',marker='*',linewidth=4)
plt.plot(rounds, mean_accuracy2, label=f'Average(5-9)',marker='X',linewidth=4)

ax.margins(x=0.03, y=0)
ax.set_xlabel('Rounds', fontsize=40)
# axins.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
ax.tick_params(axis='x', labelsize=25)
ax.tick_params(axis='y', labelsize=25)
# axins.set_xlim(38, 42)
# axins.set_ylim(0.5, 0.75)
# # 设置 x 轴和 y 轴的刻度为整数
# axins.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
# # axins.yaxis.set_major_locator(ticker.MaxNLocator(integer=True))
# axins.tick_params(axis='x', labelsize=25)
# axins.tick_params(axis='y', labelsize=25)

# ax.legend(loc=(1.8, 0), fontsize=14.5)
ax.legend(loc=(0.0,1.03),fontsize=22.5, frameon=False, ncol=3)
ax.grid(True)
plt.show()

# %%
# 8.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
setting_name = 'Direction_VHvsVHR_GB'
analysis_list =['RandomUnderSampler','IncrementalSampling','Triplets','RandomOverSampler','No','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#038583','red','#0c8d4a','#603076','#394793','tab:green', 'tab:purple', 'tab:cyan','#FF5200']
# label_list = ['Balanced','BtoL','BtoM','BtoH','BtoVH']
label_list = ['RUS','Our','Triplets','ROS','No','CNN']
line_styles = ['--','-', '-', (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
# line_styles = ['--','-', '-', '-', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = [None,None,'p','x','s','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    # metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    metric_path = os.path.join(base_path,algorithm,setting_name,f'{analysis}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 6, label=label_list[i], linewidth=3)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 9'Correlation2'
# 7.异步Rc1c2_Asyn_step7
# analysis_list = ['Balanced','Cov9B_SeverityVH','CovH_SeverityVH','Cov1B_SeverityVH','CovA_SeverityVH','CovA_severityVHR']
# 6,covertype
# sevrity - diffrent level IR from
# 2.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
# setting_name = 'CovA_Abrupt_BtoVH'
analysis_list = ['Balanced','Correlation2']
# analysis_list =['IncrementalSampling','RandomUnderSampler','Triplets','RandomOverSampler','no','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#3b5489','black', '#59b9d0', '#e8513a', '#3e6999','#f39d82']
label_list = ['all-B','Independent']
# label_list = ['RandomUnderSampler','IncrementalSampling(Ours)','Triplets','RandomOverSampler','CondensedNearestNeighbour','No-Sampling']
line_styles = ['-','--', '-', '-', '-',(0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = ['s','*','p','o','|','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 8, label=label_list[i], linewidth=4)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])

# list_df_dirF = []
# # E:\Fedstream\metrics\130K_binary_client_Sampling\FedNova\Rc1c2_Asyn_step7\no_epoch200_1/client_0_metrics.csv
# for j in range(10):
#     metric_path1 = os.path.join(base_path,algorithm,'Correlation2',f'{sampling_name}_epoch200_1',f'client_{j}_metrics.csv')
#     # metric_path2 = os.path.join(base_path,algorithm,setting_name,f'{sampling_name}_epoch200_1',f'client_{j+5}_metrics.csv')
#     df1 =pd.read_csv(metric_path1)
#     # df2 = pd.read_csv(metric_path2)
#     grouped_data1 = df1.groupby('rounds')['accuracy'].mean()
#     # grouped_data2 = df2.groupby('rounds')['accuracy'].mean()
#     list_df_dirF.append(grouped_data1)
#     # list_df_dirB.append(grouped_data2)
#
#  # 将list中的所有数据框按列拼接
# combined_df1 = pd.concat(list_df_dirF, axis=1)
# # combined_df2 = pd.concat(list_df_dirB, axis=1)
#
# # 计算每一行的平均值
# averaged_data1 = combined_df1.mean(axis=1)
# # averaged_data2 = combined_df2.mean(axis=1)
#
# # 获取 rounds 和平均 accuracy
# rounds = averaged_data1.index.values
# mean_accuracy1 = averaged_data1.values
# # mean_accuracy2 = averaged_data2.values
#
# # 绘制准确率图表
# plt.plot(rounds, mean_accuracy1, label=f'Average',marker='*',linewidth=4)
# # plt.plot(rounds, mean_accuracy2, label=f'Mean-half(5-9)',marker='X',linewidth=4)
# # 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16
# 显示图例和网格线, frameon=False去除外边框
ax.legend(loc=(0.02,1.02),fontsize=30, frameon=False, ncol=3)

ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()
poker

# %%
# 8.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
setting_name = 'Correlation2'
analysis_list =['RandomUnderSampler','IncrementalSampling','Triplets','RandomOverSampler','No','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#038583','#e62816','#0c8d4a','#603076','#394793','tab:green', 'tab:purple', 'tab:cyan','#FF5200']
# label_list = ['Balanced','BtoL','BtoM','BtoH','BtoVH']
label_list = ['RUS','Our','Triplets','ROS','No','CNN']
line_styles = ['--','-', '-', (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
# line_styles = ['--','-', '-', '-', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = [None,None,'p','x','s','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    # metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    metric_path = os.path.join(base_path,algorithm,setting_name,f'{analysis}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 6, label=label_list[i], linewidth=3)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# 8.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
setting_name = 'CovA_severityVH'
analysis_list =['RandomUnderSampler','IncrementalSampling','Triplets','RandomOverSampler','No','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#038583','red','#0c8d4a','#603076','#394793','tab:green', 'tab:purple', 'tab:cyan','#FF5200']
# label_list = ['Balanced','BtoL','BtoM','BtoH','BtoVH']
label_list = ['RUS','Our','Triplets','ROS','No','CNN']
line_styles = ['--','-', '-', (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
# line_styles = ['--','-', '-', '-', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = [None,None,'p','x','s','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    # metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    metric_path = os.path.join(base_path,algorithm,setting_name,f'{analysis}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 6, label=label_list[i], linewidth=3)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()

# %%
# electricity-100
# no
# [0.70649,0.70857,0.702858,0.701534,0.71025,0.705616]
# rus
# [0.73927,0.691162,0.667329,0.729339,0.735849]
# ros
# [0.7206,0.728787,0.691714,0.729118,0.71003]
# cnn
# [0.566,0.7174,0.5690,0.6049,0.7119]
# trip
# [0.723,0.725,0.726,0.725,0.721]
# ours
# [0.7183,0.7128,0.7174,0.7125,0.7104]
import numpy as np
from scipy import stats

# 定义数据
data = {
    "no": [0.70649, 0.70857, 0.702858, 0.701534, 0.71025, 0.705616],
    "rus": [0.73927, 0.691162, 0.667329, 0.729339, 0.735849],
    "ros": [0.7206, 0.728787, 0.691714, 0.729118, 0.71003],
    "cnn": [0.566, 0.7174, 0.5690, 0.6049, 0.7119],
    "trip": [0.723, 0.725, 0.726, 0.725, 0.721],
    "ours": [0.7183, 0.7128, 0.7174, 0.7125, 0.7104]
}

# 计算均值和置信区间
def calculate_stats(values):
    mean = np.mean(values)
    ci = stats.t.interval(0.95, len(values) - 1, loc=np.mean(values), scale=stats.sem(values))
    return mean, ci

# 打印结果
for method, values in data.items():
    mean, ci = calculate_stats(values)
    print(f"{method}: Mean = {mean}, Confidence Interval = {ci}")
# 打印结果
for method, values in data.items():
    mean, ci = calculate_stats(values)
    lower_ci = mean - ci[0]
    upper_ci = ci[1] - mean
    print(f"{method}: Mean = {mean*100:.4f} ± {upper_ci*100:.4f}")
# Out:
# no: Mean = 0.7058863333333334, Confidence Interval = (0.7024122494279512, 0.7093604172387156)
# rus: Mean = 0.7125898, Confidence Interval = (0.6731239742631021, 0.752055625736898)
# ros: Mean = 0.7160498000000001, Confidence Interval = (0.6965930044975321, 0.735506595502468)
# cnn: Mean = 0.63384, Confidence Interval = (0.5402617474990704, 0.7274182525009295)
# trip: Mean = 0.724, Confidence Interval = (0.7215166720035925, 0.7264833279964075)
# ours: Mean = 0.71428, Confidence Interval = (0.7100552393865086, 0.7185047606134914)
# no: Mean = 70.5886 ± 0.3474
# rus: Mean = 71.2590 ± 3.9466
# ros: Mean = 71.6050 ± 1.9457
# cnn: Mean = 63.3840 ± 9.3578
# trip: Mean = 72.4000 ± 0.2483
# ours: Mean = 71.4280 ± 0.4225

# %%
#
import numpy as np
from scipy import stats

# 定义数据
data = {
    "no": [0.704292, 0.6834,0.6824,0.6802,0.6882],
    "rus": [0.6961,0.6916,0.7,0.7071,0.7093],
    "ros": [0.6955,0.698,0.6996,0.698,0.7041],
    "cnn": [0.6314,0.6753,0.5902,0.6468,0.6472],
    "trip": [0.7080, 0.6993,0.7032,0.6924,0.6948],
    "ours": [0.6836,0.6950,0.6641,0.7014,0.7041]
}

# 计算均值和置信区间
def calculate_stats(values):
    mean = np.mean(values)
    ci = stats.t.interval(0.95, len(values) - 1, loc=np.mean(values), scale=stats.sem(values))
    return mean, ci

# 打印结果
for method, values in data.items():
    mean, ci = calculate_stats(values)
    print(f"{method}: Mean = {mean}, Confidence Interval = {ci}")
# 打印结果
for method, values in data.items():
    mean, ci = calculate_stats(values)
    lower_ci = mean - ci[0]
    upper_ci = ci[1] - mean
    print(f"{method}: Mean = {mean*100:.2f}$\pm${upper_ci*100:.3f}")

"""
no: Mean = 68.77$\pm$1.208
rus: Mean = 70.08$\pm$0.919
ros: Mean = 69.90$\pm$0.396
cnn: Mean = 63.82$\pm$3.868
trip: Mean = 69.95$\pm$0.782
ours: Mean = 68.96$\pm$2.026
"""
# Out:
# no: Mean = 0.6876984, Confidence Interval = (0.6756220693531098, 0.6997747306468903)
# rus: Mean = 0.70082, Confidence Interval = (0.6916260670851296, 0.7100139329148704)
# ros: Mean = 0.6990399999999999, Confidence Interval = (0.6950835900799496, 0.7029964099200502)
# cnn: Mean = 0.63818, Confidence Interval = (0.5995005820215059, 0.676859417978494)
# trip: Mean = 0.69954, Confidence Interval = (0.6917246152548733, 0.7073553847451268)
# ours: Mean = 0.68964, Confidence Interval = (0.6693805861749449, 0.7098994138250552)
# no: Mean = 68.77$\pm$1.208
# rus: Mean = 70.08$\pm$0.919
# ros: Mean = 69.90$\pm$0.396
# cnn: Mean = 63.82$\pm$3.868
# trip: Mean = 69.95$\pm$0.782
# ours: Mean = 68.96$\pm$2.026
# ''

# %%
#
import numpy as np
from scipy import stats

# 定义数据
data = {
    "no": [0.6863,0.6854,0.6853,0.6901,0.6877],
    "rus": [0.6852,0.6918,0.6849,0.6885,0.6813],
    "ros": [0.6867,0.6780,0.6803,0.6867,0.6833],
    "cnn": [0.56,0.6395,0.6594,0.6395,0.6],
    "trip": [0.69,0.6898,0.6831,0.6741,0.6834],
    "ours": [0.6474,0.650,0.664,0.662,0.664]
}

# 计算均值和置信区间
def calculate_stats(values):
    mean = np.mean(values)
    ci = stats.t.interval(0.95, len(values) - 1, loc=np.mean(values), scale=stats.sem(values))
    return mean, ci

# 打印结果
for method, values in data.items():
    mean, ci = calculate_stats(values)
    print(f"{method}: Mean = {mean}, Confidence Interval = {ci}")
# 打印结果
for method, values in data.items():
    mean, ci = calculate_stats(values)
    lower_ci = mean - ci[0]
    upper_ci = ci[1] - mean
    print(f"{method}: Mean = {mean*100:.2f}$\pm${upper_ci*100:.3f}")
"""
no: Mean = 68.70$\pm$0.249
rus: Mean = 68.63$\pm$0.494
ros: Mean = 68.30$\pm$0.480
cnn: Mean = 61.97$\pm$4.933
trip: Mean = 68.41$\pm$0.807
ours: Mean = 65.75$\pm$1.007
"""
# Out:
# no: Mean = 0.6869600000000001, Confidence Interval = (0.68447418991602, 0.6894458100839802)
# rus: Mean = 0.6863400000000001, Confidence Interval = (0.6814024532065635, 0.6912775467934367)
# ros: Mean = 0.683, Confidence Interval = (0.6782006835385168, 0.6877993164614833)
# cnn: Mean = 0.61968, Confidence Interval = (0.5703547199003985, 0.6690052800996015)
# trip: Mean = 0.68408, Confidence Interval = (0.6760142477688241, 0.6921457522311759)
# ours: Mean = 0.6574800000000001, Confidence Interval = (0.6474116437756408, 0.6675483562243594)
# no: Mean = 68.70$\pm$0.249
# rus: Mean = 68.63$\pm$0.494
# ros: Mean = 68.30$\pm$0.480
# cnn: Mean = 61.97$\pm$4.933
# trip: Mean = 68.41$\pm$0.807
# ours: Mean = 65.75$\pm$1.007
# ''

# %%
#
import numpy as np
from scipy import stats

# 定义数据
data = {
    "no": [0.7107, 0.71596,0.738,0.7298,0.7181,0.7272],
    "rus": [0.7857,0.7775,0.7899,0.7792,0.7706],
    "ros": [0.8612,0.8720,0.8707,0.8749,0.9065],
    "cnn": [0.84,0.7957,0.8386,0.8585,0.8264],
    "trip": [0.8353,0.8437,0.8464,0.8321,0.8458],
    "ours": [0.9554,0.9546,0.9530,0.9546,0.9507,0.9560]
}

# 计算均值和置信区间
def calculate_stats(values):
    mean = np.mean(values)
    ci = stats.t.interval(0.95, len(values) - 1, loc=np.mean(values), scale=stats.sem(values))
    return mean, ci

# 打印结果
for method, values in data.items():
    mean, ci = calculate_stats(values)
    print(f"{method}: Mean = {mean}, Confidence Interval = {ci}")
# 打印结果
for method, values in data.items():
    mean, ci = calculate_stats(values)
    lower_ci = mean - ci[0]
    upper_ci = ci[1] - mean
    print(f"{method}: Mean = {mean*100:.2f}$\pm${upper_ci*100:.3f}")
'''
no: Mean = 72.33$\pm$1.063
rus: Mean = 78.06$\pm$0.929
ros: Mean = 87.71$\pm$2.141
cnn: Mean = 83.18$\pm$2.885
trip: Mean = 84.07$\pm$0.811
ours: Mean = 95.41$\pm$0.202
'''
# Out:
# no: Mean = 0.7232933333333333, Confidence Interval = (0.7126610914088991, 0.7339255752577676)
# rus: Mean = 0.7805799999999999, Confidence Interval = (0.7712868272086646, 0.7898731727913353)
# ros: Mean = 0.8770600000000002, Confidence Interval = (0.8556527980076327, 0.8984672019923676)
# cnn: Mean = 0.83184, Confidence Interval = (0.8029948064081981, 0.860685193591802)
# trip: Mean = 0.8406600000000001, Confidence Interval = (0.8325507837801905, 0.8487692162198096)
# ours: Mean = 0.95405, Confidence Interval = (0.9520283718021488, 0.9560716281978511)
# no: Mean = 72.33$\pm$1.063
# rus: Mean = 78.06$\pm$0.929
# ros: Mean = 87.71$\pm$2.141
# cnn: Mean = 83.18$\pm$2.885
# trip: Mean = 84.07$\pm$0.811
# ours: Mean = 95.41$\pm$0.202
# '\nours30: Mean = 71.01$\\pm$1.057\nours50: Mean = 70.14$\\pm$3.687\n'

# %%
#
import numpy as np
from scipy import stats

# 定义数据
data = {

    "ours30": [0.7057,0.721,0.7044,0.7173,0.7019],
    "ours50": [0.7234,0.7216,0.6696,0.7241,0.6681]
}

# 计算均值和置信区间
def calculate_stats(values):
    mean = np.mean(values)
    ci = stats.t.interval(0.95, len(values) - 1, loc=np.mean(values), scale=stats.sem(values))
    return mean, ci

# 打印结果
for method, values in data.items():
    mean, ci = calculate_stats(values)
    print(f"{method}: Mean = {mean}, Confidence Interval = {ci}")
# 打印结果
for method, values in data.items():
    mean, ci = calculate_stats(values)
    lower_ci = mean - ci[0]
    upper_ci = ci[1] - mean
    print(f"{method}: Mean = {mean*100:.2f}$\pm${upper_ci*100:.3f}")
'''
ours30: Mean = 71.01$\pm$1.057
ours50: Mean = 70.14$\pm$3.687
'''

# %%
import pandas as pd
p = 'E:/Real DataSet/elecNorm/train_dataset.csv'
df = pd.read_csv(p)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36249 entries, 0 to 36248
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       36249 non-null  float64
#  1   day        36249 non-null  int64
#  2   period     36249 non-null  float64
#  3   nswprice   36249 non-null  float64
#  4   nswdemand  36249 non-null  float64
#  5   vicprice   36249 non-null  float64
#  6   vicdemand  36249 non-null  float64
#  7   transfer   36249 non-null  float64
#  8   target     36249 non-null  int64
# dtypes: float64(7), int64(2)
# memory usage: 2.5 MB
# None

# %%
class_counts = df['target'].value_counts()
print(class_counts)
# Out:
# target
# 1    20884
# 0    15365
# Name: count, dtype: int64

# %%
# 8.实验分析，
# 研究内容，覆盖率对全局模型的影响
# 研究方法 all-balanced[50,50],one-imbalance(cov9B),half-imbalance(covH),9-imbalance(cov1B),covA_VH(all is 98/2),covA_VHR(all is 2/98)
import os
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = 'SimHei'
plt.rcParams['axes.unicode_minus'] = False

algorithm = 'FedNova'
# base_path = 'E:/FedStream/metrics/130K_binary_client_Sampling'
setting_name = 'CovA'
analysis_list =['RandomUnderSampler','IncrementalSampling','Triplets','RandomOverSampler','No','CondensedNearestNeighbour']
sampling_name = 'no'
analysis_file = 'global_back.csv'
# rounds,accuracy,auc,kappa,g_mean,recall_micro,precision_micro,recall_macro,precision_macro,recall_0,precision_0,f1_score_0,recall_1,precision_1,f1_score_1
analysis_parameter = 'accuracy'
# read_result_path_list = []
fig, ax = plt.subplots(figsize=(10, 7))
# fig1, ax1 = plt.subplots(figsize=(15, 6))
# axins = ax.inset_axes([0.23, 0.05, 0.5, 0.50])  # 放大视图位置和大小
color_list = ['#038583','#e62816','#0c8d4a','#603076','#394793','tab:green', 'tab:purple', 'tab:cyan','#FF5200']
# label_list = ['Balanced','BtoL','BtoM','BtoH','BtoVH']
label_list = ['RUS','Our','Triplets','ROS','No','CNN']
line_styles = ['--','-', '-', (0, (3, 1, 1, 1)), (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
# line_styles = ['--','-', '-', '-', (0, (3, 1, 1, 1)),(0, (5, 1, 1, 1, 1, 1)) ]
markers = [None,None,'p','x','s','o' ]


for i,analysis in enumerate(analysis_list):
    # E:\FedStream\metrics\130K_binary_client_Sampling\FedProx\CovA_Abrupt_BtoVH\CondensedNearestNeighbour_epoch200_1
    # metric_path = os.path.join(base_path,algorithm,analysis,f'{sampling_name}_epoch200_1','global_back.csv')
    metric_path = os.path.join(base_path,algorithm,setting_name,f'{analysis}_epoch200_1','global_back.csv')
    # read_result_path_list.append(path)
    # print(f"{i}:",path)
    df = pd.read_csv(metric_path)
        # 提取准确率数据
    # accuracy = df['accuracy']
    grouped_data = df.groupby('rounds')['accuracy'].mean()#.apply(list).reset_index() # .mean()
    rounds = grouped_data.index.values
    mean_accuracy = grouped_data.values
    # x = np.arange(len(accuracy))

    # 绘制准确率图表
    ax.plot(rounds, mean_accuracy, color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 6, label=label_list[i], linewidth=3)
    #ax1.plot(rounds[19:71], mean_accuracy[19:71], color=color_list[i],linestyle=line_styles[i],marker = markers[i],markersize = 7, label=label_list[i])
# 设置 x 轴和 y 轴的刻度标签属性
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontweight('bold')
ax.set_xlim([-0.5, 100])
ax.set_ylim([0.485, 0.948])
ax.margins(x=0, y=0)
ax.set_xlabel('Rounds', fontsize=40)
ax.set_ylabel('Test Accuracy', fontsize=40)
# 修改x轴和y轴的标尺字体大小
ax.tick_params(axis='x', labelsize=30)  # 设置x轴标尺字体大小为16
ax.tick_params(axis='y', labelsize=30)  # 设置y轴标尺字体大小为16

# 显示图例和网格线, frameon=False去除外边框
#ax.legend(loc=(0.0,1.02),fontsize=16, frameon=False, ncol=len(label_list)*1.5)
ax.legend(loc =(0.0,1.02),fontsize=28, frameon=False,ncol = 3)
ax.grid(True)
# plt.savefig('C:/Users/张腾森/Desktop/severity1.pdf')
plt.show()
